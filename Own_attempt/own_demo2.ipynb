# %%
from cube_env import CubeEnv
from gflownet import GFlowNet

# %%
env = CubeEnv(dim=2, size=8)
agent = GFlowNet(env)

# %%
agent.dim
# Out:
# 2

# %%
agent.train(50, batch_size=10)
# Out:
# ...
# 32/32 [==============================] - 0s 2ms/step
# Epoch: 0 Loss: 7.79616117477417
# Epoch: 5 Loss: 3.1618800163269043
# Epoch: 10 Loss: 1.9032291173934937
# Epoch: 15 Loss: 0.9376272559165955
# Epoch: 20 Loss: 0.5849084854125977
# Epoch: 25 Loss: 0.2929070293903351
# Epoch: 30 Loss: 0.21970772743225098
# Epoch: 35 Loss: 0.08666490018367767
# Epoch: 40 Loss: 0.12517620623111725
# Epoch: 45 Loss: 0.05954572185873985
# [7.796161,
#  6.300484,
#  4.0867605,
#  3.706101,
#  3.1976604,
#  3.16188,
#  3.3298874,
#  2.7785175,
#  2.4996107,
#  2.1516902,
#  1.9032291,
#  1.5231383,
#  1.3519595,
#  1.5983713,
#  1.2848316,
#  0.93762726,
#  0.8619352,
#  1.03363,
#  0.8867256,
#  0.6764025,
#  0.5849085,
#  0.54074943,
#  0.5362961,
#  0.47260973,
#  0.37814206,
#  0.29290703,
#  0.31172222,
#  0.2196679,
#  0.20461312,
#  0.19031906,
#  0.21970773,
#  0.16475143,
#  0.2882426,
#  0.1598071,
#  0.09815018,
#  0.0866649,
#  0.0673032,
#  0.059737258,
#  0.061478462,
#  0.09382441,
# ...

# %%
agent.plot_policy_2d()
# Out:
# 2/2 [==============================] - 0s 4ms/step

# %%
env.plot_reward_2d()

# %%
agent.sample(5000)
agent.plot_sampled_data_2d()
# Out:
# ...
# 157/157 [==============================] - 0s 1ms/step
